# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# matplotlib==3.9.0
# numpy==1.26.4
# pandas==2.2.2
# seaborn==0.13.2
# C:\Users\MILLEX\AppData\Local\Temp\ipykernel_27424\3708299036.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
df = pd.read_csv('GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 6.430699
# iter 20. reward: 8.085499
# iter 30. reward: 17.363550
# iter 40. reward: 17.644801
# iter 50. reward: 21.796852
# iter 60. reward: 26.775851
# iter 70. reward: 24.516703
# iter 80. reward: 26.636402
# iter 90. reward: 30.039603
# iter 100. reward: 30.459501
# iter 110. reward: 27.782402
# iter 120. reward: 28.758301
# iter 130. reward: 30.099802
# iter 140. reward: 26.815599
# iter 150. reward: 20.774601
# iter 160. reward: 29.304701
# iter 170. reward: 28.608699
# iter 180. reward: 29.571950
# iter 190. reward: 28.272198
# iter 200. reward: 30.318450
# iter 210. reward: 31.349500
# iter 220. reward: 30.007650
# iter 230. reward: 29.527949
# iter 240. reward: 30.226301
# iter 250. reward: 30.489849
# iter 260. reward: 31.473150
# iter 270. reward: 30.506000
# iter 280. reward: 31.171951
# iter 290. reward: 30.142351
# iter 300. reward: 22.838899
# iter 310. reward: 31.538301
# iter 320. reward: 28.743950
# iter 330. reward: 30.598700
# iter 340. reward: 31.985699
# iter 350. reward: 31.540099
# iter 360. reward: 32.356199
# iter 370. reward: 31.974750
# iter 380. reward: 31.751900
# iter 390. reward: 33.734800
# iter 400. reward: 33.692600
# iter 410. reward: 23.718501
# iter 420. reward: 31.913851
# iter 430. reward: 33.286400
# iter 440. reward: 32.584700
# iter 450. reward: 31.759100
# iter 460. reward: 33.430400
# iter 470. reward: 32.045400
# iter 480. reward: 33.488400
# iter 490. reward: 33.002000
# iter 500. reward: 32.247500
# time taken to train: 276.37703585624695 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 1: buy 1 unit at price 762.130005, total balance 9237.869995
# day 2: buy 1 unit at price 762.020020, total balance 8475.849975
# day 5, sell 1 unit at price 785.309998, investment 3.041475 %, total balance 9261.159973,
# day 6: buy 1 unit at price 762.559998, total balance 8498.599975
# day 7: buy 1 unit at price 754.020020, total balance 7744.579955
# day 8: buy 1 unit at price 736.080017, total balance 7008.499938
# day 9: buy 1 unit at price 758.489990, total balance 6250.009948
# day 10: buy 1 unit at price 764.479980, total balance 5485.529968
# day 12: buy 1 unit at price 760.539978, total balance 4724.989990
# day 15, sell 1 unit at price 760.989990, investment -0.135171 %, total balance 5485.979980,
# day 16: buy 1 unit at price 761.679993, total balance 4724.299987
# day 18: buy 1 unit at price 770.840027, total balance 3953.459960
# day 19: buy 1 unit at price 758.039978, total balance 3195.419982
# day 20: buy 1 unit at price 747.919983, total balance 2447.499999
# day 21: buy 1 unit at price 750.500000, total balance 1696.999999
# day 22: buy 1 unit at price 762.520020, total balance 934.479979
# day 23: buy 1 unit at price 759.109985, total balance 175.369994
# day 26, sell 1 unit at price 789.289978, investment 3.505295 %, total balance 964.659972,
# day 27: buy 1 unit at price 789.270020, total balance 175.389952
# day 28, sell 1 unit at price 796.099976, investment 5.580748 %, total balance 971.489928,
# day 29: buy 1 unit at price 797.070007, total balance 174.419921
# day 30, sell 1 unit at price 797.849976, investment 8.391745 %, total balance 972.269897,
# day 31: buy 1 unit at price 790.799988, total balance 181.469909
# day 34, sell 1 unit at price 794.559998, investment 4.755502 %, total balance 976.029907,
# day 35: buy 1 unit at price 791.260010, total balance 184.769897
# day 37, sell 1 unit at price 791.549988, investment 3.540970 %, total balance 976.319885,
# day 39, sell 1 unit at price 782.789978, investment 2.925553 %, total balance 1759.109863,
# day 41: buy 1 unit at price 786.140015, total balance 972.969848
# day 42: buy 1 unit at price 786.900024, total balance 186.069824
# day 43, sell 1 unit at price 794.020020, investment 4.245881 %, total balance 980.089844,
# day 45, sell 1 unit at price 806.650024, investment 4.645581 %, total balance 1786.739868,
# day 46: buy 1 unit at price 804.789978, total balance 981.949890
# day 47, sell 1 unit at price 807.909973, investment 6.578808 %, total balance 1789.859863,
# day 48, sell 1 unit at price 806.359985, investment 7.813670 %, total balance 2596.219848,
# day 49, sell 1 unit at price 807.880005, investment 7.645570 %, total balance 3404.099853,
# day 50: buy 1 unit at price 804.609985, total balance 2599.489868
# day 52: buy 1 unit at price 802.174988, total balance 1797.314880
# day 54, sell 1 unit at price 819.309998, investment 7.447670 %, total balance 2616.624878,
# day 56, sell 1 unit at price 835.669983, investment 10.085495 %, total balance 3452.294861,
# day 58, sell 1 unit at price 823.309998, investment 4.312843 %, total balance 4275.604859,
# day 59: buy 1 unit at price 802.320007, total balance 3473.284852
# day 60: buy 1 unit at price 796.789978, total balance 2676.494874
# day 61: buy 1 unit at price 795.695007, total balance 1880.799867
# day 62: buy 1 unit at price 798.530029, total balance 1082.269838
# day 63: buy 1 unit at price 801.489990, total balance 280.779848
# day 67, sell 1 unit at price 809.559998, investment 1.566988 %, total balance 1090.339846,
# day 69, sell 1 unit at price 819.239990, investment 3.596358 %, total balance 1909.579836,
# day 71: buy 1 unit at price 818.979980, total balance 1090.599856
# day 72: buy 1 unit at price 824.159973, total balance 266.439883
# day 73, sell 1 unit at price 828.070007, investment 4.652073 %, total balance 1094.509890,
# day 74: buy 1 unit at price 831.659973, total balance 262.849917
# day 75, sell 1 unit at price 830.760010, investment 5.675833 %, total balance 1093.609927,
# day 77, sell 1 unit at price 828.640015, investment 5.304358 %, total balance 1922.249942,
# day 78, sell 1 unit at price 829.280029, investment 3.043036 %, total balance 2751.529971,
# day 79: buy 1 unit at price 823.210022, total balance 1928.319949
# day 80: buy 1 unit at price 835.239990, total balance 1093.079959
# day 81: buy 1 unit at price 830.630005, total balance 262.449954
# day 82, sell 1 unit at price 829.080017, investment 3.041229 %, total balance 1091.529971,
# day 84, sell 1 unit at price 831.909973, investment 3.706795 %, total balance 1923.439944,
# day 86, sell 1 unit at price 838.679993, investment 4.531856 %, total balance 2762.119937,
# day 87, sell 1 unit at price 843.250000, investment 5.830899 %, total balance 3605.369937,
# day 88, sell 1 unit at price 845.539978, investment 6.264331 %, total balance 4450.909915,
# day 89, sell 1 unit at price 845.619995, investment 5.897081 %, total balance 5296.529910,
# day 90, sell 1 unit at price 847.200012, investment 5.703131 %, total balance 6143.729922,
# day 91, sell 1 unit at price 848.780029, investment 3.638679 %, total balance 6992.509951,
# day 92, sell 1 unit at price 852.119995, investment 3.392548 %, total balance 7844.629946,
# day 93: buy 1 unit at price 848.400024, total balance 6996.229922
# day 94: buy 1 unit at price 830.460022, total balance 6165.769900
# day 95: buy 1 unit at price 829.590027, total balance 5336.179873
# day 96: buy 1 unit at price 817.580017, total balance 4518.599856
# day 97: buy 1 unit at price 814.429993, total balance 3704.169863
# day 98: buy 1 unit at price 819.510010, total balance 2884.659853
# day 102, sell 1 unit at price 829.559998, investment -0.252504 %, total balance 3714.219851,
# day 104, sell 1 unit at price 834.570007, investment 1.379962 %, total balance 4548.789858,
# day 105: buy 1 unit at price 831.409973, total balance 3717.379885
# day 106: buy 1 unit at price 827.880005, total balance 2889.499880
# day 107: buy 1 unit at price 824.669983, total balance 2064.829897
# day 108: buy 1 unit at price 824.729980, total balance 1240.099917
# day 109: buy 1 unit at price 823.349976, total balance 416.749941
# day 119, sell 1 unit at price 871.729980, investment 4.368803 %, total balance 1288.479921,
# day 122, sell 1 unit at price 912.570007, investment 9.864802 %, total balance 2201.049928,
# day 123, sell 1 unit at price 916.440002, investment 8.019799 %, total balance 3117.489930,
# day 124, sell 1 unit at price 927.039978, investment 11.629694 %, total balance 4044.529908,
# day 125, sell 1 unit at price 931.659973, investment 12.303661 %, total balance 4976.189881,
# day 126, sell 1 unit at price 927.130005, investment 13.399299 %, total balance 5903.319886,
# day 127, sell 1 unit at price 934.299988, investment 14.718269 %, total balance 6837.619874,
# day 128: buy 1 unit at price 932.169983, total balance 5905.449891
# day 129, sell 1 unit at price 928.780029, investment 13.333580 %, total balance 6834.229920,
# day 130: buy 1 unit at price 930.599976, total balance 5903.629944
# day 131: buy 1 unit at price 932.219971, total balance 4971.409973
# day 133, sell 1 unit at price 943.000000, investment 13.421781 %, total balance 5914.409973,
# day 134, sell 1 unit at price 919.619995, investment 11.081315 %, total balance 6834.029968,
# day 137, sell 1 unit at price 941.859985, investment 14.210533 %, total balance 7775.889953,
# day 138, sell 1 unit at price 948.820007, investment 15.046140 %, total balance 8724.709960,
# day 139, sell 1 unit at price 954.960022, investment 15.984703 %, total balance 9679.669982,
# day 141, sell 1 unit at price 971.469971, investment 4.215968 %, total balance 10651.139953,
# day 142, sell 1 unit at price 975.880005, investment 4.865681 %, total balance 11627.019958,
# day 143, sell 1 unit at price 964.859985, investment 3.501321 %, total balance 12591.879943,
# day 145: buy 1 unit at price 975.599976, total balance 11616.279967
# day 147, sell 1 unit at price 976.570007, investment 0.099429 %, total balance 12592.849974,
# day 149: buy 1 unit at price 983.409973, total balance 11609.440001
# day 150: buy 1 unit at price 949.830017, total balance 10659.609984
# day 151: buy 1 unit at price 942.900024, total balance 9716.709960
# day 153: buy 1 unit at price 950.760010, total balance 8765.949950
# day 155: buy 1 unit at price 939.780029, total balance 7826.169921
# day 157, sell 1 unit at price 950.630005, investment -3.333296 %, total balance 8776.799926,
# day 158, sell 1 unit at price 959.450012, investment 1.012812 %, total balance 9736.249938,
# day 159, sell 1 unit at price 957.090027, investment 1.504932 %, total balance 10693.339965,
# day 161, sell 1 unit at price 952.270020, investment 0.158821 %, total balance 11645.609985,
# day 162: buy 1 unit at price 927.330017, total balance 10718.279968
# day 163: buy 1 unit at price 940.489990, total balance 9777.789978
# day 164: buy 1 unit at price 917.789978, total balance 8860.000000
# day 165: buy 1 unit at price 908.729980, total balance 7951.270020
# day 166: buy 1 unit at price 898.700012, total balance 7052.570008
# day 173, sell 1 unit at price 947.159973, investment 0.785284 %, total balance 7999.729981,
# day 175, sell 1 unit at price 953.419983, investment 2.813450 %, total balance 8953.149964,
# day 176: buy 1 unit at price 965.400024, total balance 7987.749940
# day 177, sell 1 unit at price 970.890015, investment 3.232360 %, total balance 8958.639955,
# day 178, sell 1 unit at price 968.150024, investment 5.487099 %, total balance 9926.789979,
# day 179, sell 1 unit at price 972.919983, investment 7.063705 %, total balance 10899.709962,
# day 180, sell 1 unit at price 980.340027, investment 9.084234 %, total balance 11880.049989,
# day 181: buy 1 unit at price 950.700012, total balance 10929.349977
# day 182, sell 1 unit at price 947.799988, investment -1.823082 %, total balance 11877.149965,
# day 183: buy 1 unit at price 934.090027, total balance 10943.059938
# day 184, sell 1 unit at price 941.530029, investment -0.964551 %, total balance 11884.589967,
# day 185: buy 1 unit at price 930.500000, total balance 10954.089967
# day 187: buy 1 unit at price 930.390015, total balance 10023.699952
# day 189, sell 1 unit at price 927.960022, investment -0.656254 %, total balance 10951.659974,
# day 191, sell 1 unit at price 926.789978, investment -0.398713 %, total balance 11878.449952,
# day 193: buy 1 unit at price 907.239990, total balance 10971.209962
# day 194: buy 1 unit at price 914.390015, total balance 10056.819947
# day 195, sell 1 unit at price 922.669983, investment -0.829763 %, total balance 10979.489930,
# day 196, sell 1 unit at price 922.219971, investment 1.651160 %, total balance 11901.709901,
# day 197: buy 1 unit at price 926.960022, total balance 10974.749879
# day 198: buy 1 unit at price 910.979980, total balance 10063.769899
# day 200: buy 1 unit at price 906.659973, total balance 9157.109926
# day 202: buy 1 unit at price 927.000000, total balance 8230.109926
# day 204: buy 1 unit at price 915.890015, total balance 7314.219911
# day 206, sell 1 unit at price 921.289978, investment 0.754597 %, total balance 8235.509889,
# day 208, sell 1 unit at price 939.330017, investment 1.334469 %, total balance 9174.839906,
# day 210: buy 1 unit at price 928.450012, total balance 8246.389894
# day 212, sell 1 unit at price 935.950012, investment 2.741008 %, total balance 9182.339906,
# day 213, sell 1 unit at price 926.500000, investment 2.188254 %, total balance 10108.839906,
# day 214: buy 1 unit at price 929.080017, total balance 9179.759889
# day 215: buy 1 unit at price 932.070007, total balance 8247.689882
# day 216, sell 1 unit at price 935.090027, investment 0.872711 %, total balance 9182.779909,
# day 217: buy 1 unit at price 925.109985, total balance 8257.669924
# day 218, sell 1 unit at price 920.289978, investment 0.480403 %, total balance 9177.959902,
# day 219: buy 1 unit at price 915.000000, total balance 8262.959902
# day 221: buy 1 unit at price 931.580017, total balance 7331.379885
# day 223, sell 1 unit at price 928.530029, investment 0.008618 %, total balance 8259.909914,
# day 225: buy 1 unit at price 924.859985, total balance 7335.049929
# day 227, sell 1 unit at price 949.500000, investment 2.197871 %, total balance 8284.549929,
# day 229, sell 1 unit at price 953.270020, investment 2.274509 %, total balance 9237.819949,
# day 231, sell 1 unit at price 951.679993, investment 2.872092 %, total balance 10189.499942,
# day 232, sell 1 unit at price 969.960022, investment 6.006560 %, total balance 11159.459964,
# day 233, sell 1 unit at price 978.890015, investment 5.078469 %, total balance 12138.349979,
# day 234, sell 1 unit at price 977.000000, investment 5.637612 %, total balance 13115.349979,
# day 235: buy 1 unit at price 972.599976, total balance 12142.750003
# day 237, sell 1 unit at price 987.830017, investment 1.565910 %, total balance 13130.580020,
# day 239: buy 1 unit at price 992.000000, total balance 12138.580020
# day 240, sell 1 unit at price 992.179993, investment 0.018144 %, total balance 13130.760013,
# day 244: buy 1 unit at price 968.450012, total balance 12162.310001
# day 245: buy 1 unit at price 970.539978, total balance 11191.770023
# day 246: buy 1 unit at price 973.330017, total balance 10218.440006
# day 247, sell 1 unit at price 972.559998, investment 0.424388 %, total balance 11191.000004,
# day 249, sell 1 unit at price 1017.109985, investment 4.798361 %, total balance 12208.109989,
# day 250, sell 1 unit at price 1016.640015, investment 4.449672 %, total balance 13224.750004,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
